# %% [markdown]
# <a href="https://colab.research.google.com/github/sapajaykumar/IFDSF/blob/main/01_Environment_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/IFDSF
# !git pull origin main
# Out:
# [Errno 2] No such file or directory: '/content/IFDSF'
# /content
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git
