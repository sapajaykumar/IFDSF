# %% [markdown]
# <a href="https://colab.research.google.com/github/sapajaykumar/IFDSF/blob/main/notebooks/00_Project_Start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

PROJECT_PATH = "/content/IFDSF"

if not os.path.exists(PROJECT_PATH):
    # !git clone https://github.com/sapajaykumar/IFDSF.git {PROJECT_PATH}

# %cd {PROJECT_PATH}

# !git pull origin main
# !pip install -q -r requirements.txt

print("✅ IFDSF Development Environment Ready")
# Out:
# Mounted at /content/drive
